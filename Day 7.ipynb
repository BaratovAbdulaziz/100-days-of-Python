# %%
words_for_day_7 = [
    'Apple', 'House', 'River', 'Chair', 'Light', 'Window', 'Jungle', 'Ocean', 'Guitar', 'Rabbit',
    'Quizzes', 'Oxygen', 'Galaxy', 'Knight', 'Pyramid', 'Zephyr', 'Xylophone', 'Euphoria', 'Rhythm', 'Sphinx',
    'Banana', 'Mountain', 'Festival', 'Elephant', 'Diamond', 'Tornado', 'Whisper', 'Glacier', 'Falcon', 'Laptop',
    'Village', 'Scorpion', 'Adventure', 'Museum', 'Library', 'Universe', 'Computer', 'Rainbow', 'Coconut', 'Phantom',
    'Horizon', 'Phoenix', 'Satellite', 'Volcano', 'Bicycle', 'Mystery', 'Alphabet', 'Butterfly', 'Chocolate', 'Puzzle',
    'Mushroom', 'Caravan', 'Courage', 'Dragonfly', 'Electricity', 'Treasure', 'Zebra', 'Astronomy', 'Boulevard', 'Cryptic',
    'Eclipse', 'Fountain', 'Harmony', 'Immortal', 'Jazz', 'Kangaroo', 'Labyrinth', 'Nebula', 'Oracle', 'Paradox',
    'Quantum', 'Radiance', 'Spectrum', 'Tsunami', 'Umbrella', 'Voyage', 'Wilderness', 'Xenon', 'Yacht', 'Zodiac',
    'Ancient', 'Behemoth', 'Cathedral', 'Dystopia', 'Ecosystem', 'Fossil', 'Gladiator', 'Hexagon', 'Illusion', 'Jubilee',
    'Kryptonite', 'Labyrinthine', 'Mandolin', 'Nebulizer', 'Obsidian', 'Palindrome', 'Quasar', 'Renaissance', 'Symphony', 'Typhoon',
    'Ultraviolet', 'Vortex', 'Wavelength', 'Xenophobia', 'Yogurt', 'Zeppelin', 'Berserk', 'Cascade', 'Desolate', 'Ephemeral',
    'Fractal', 'Gargoyle', 'Helix', 'Infinity', 'Jigsaw', 'Kilometer', 'Luminous', 'Monolith', 'Nucleus', 'Oblivion',
    'Pyramid', 'Quagmire', 'Resonance', 'Silhouette', 'Tesseract', 'Utopia', 'Vigilante', 'Whirlpool', 'Xylophone', 'Yonder',
    'Zoology', 'Aurora', 'Blizzard', 'Crescent', 'Dragon', 'Equinox', 'Flamingo', 'Geyser', 'Hologram', 'Icicle',
    'Jaguar', 'Kaleidoscope', 'Lantern', 'Meteor', 'Nautilus', 'Oasis', 'Phoenix', 'Quartz', 'Raspberry', 'Sapphire',
    'Tundra', 'Universe', 'Vampire', 'Waterfall', 'Xerox', 'Yeti', 'Zenith', 'Arcade', 'Balloon', 'Canyon',
    'Dolphin', 'Empire', 'Feather', 'Galaxy', 'Hurricane', 'Igloo', 'Jungle', 'Kite', 'Lighthouse', 'Mermaid',
    'Nebula', 'Ocelot', 'Pegasus', 'Quicksand', 'Rattlesnake', 'Stalactite', 'Thunderstorm', 'Underworld', 'Vortex', 'Wombat',
    'X-ray', 'Yellowstone', 'Zephyr', 'Amethyst', 'Banyan', 'Cascade', 'Dragonfruit', 'Eruption', 'Fjord', 'Glacier',
    'Hummingbird', 'Icicle', 'Jasmine', 'Kelp', 'Lynx', 'Mimosa', 'Nightingale', 'Opal', 'Penguin', 'Quartz',
    'Rainforest', 'Sandstorm', 'Tornado', 'Ultramarine', 'Volcano', 'Whisper', 'Xenolith', 'Yew', 'Zebra',
    'Aurora', 'Balloon', 'Crescent', 'Dolphin', 'Empire', 'Feather', 'Galaxy', 'Hurricane', 'Igloo', 'Jungle',
    'Kite', 'Lighthouse', 'Mermaid', 'Nebula', 'Ocelot', 'Pegasus', 'Quicksand', 'Rattlesnake', 'Stalactite', 'Thunderstorm',
    'Underworld', 'Vortex', 'Wombat', 'X-ray', 'Yellowstone', 'Zephyr', 'Amethyst', 'Banyan', 'Cascade', 'Dragonfruit',
    'Eruption', 'Fjord', 'Glacier', 'Hummingbird', 'Icicle', 'Jasmine', 'Kelp', 'Lynx', 'Mimosa', 'Nightingale',
    'Opal', 'Penguin', 'Quartz', 'Rainforest', 'Sandstorm', 'Tornado', 'Ultramarine', 'Volcano', 'Whisper', 'Xenolith',
    'Yew', 'Zebra', 'Asteroid', 'Bamboo', 'Caribou', 'Dandelion', 'Eagle', 'Flamethrower', 'Gargantuan', 'Holograph',
    'Indigo', 'Jackal', 'Kookaburra', 'Lemur', 'Molecule', 'Nectarine', 'Osprey', 'Pineapple', 'Quartzite', 'Ravine',
    'Sundial', 'Teardrop', 'Uranium', 'Velvet', 'Warrior', 'Xenophobe', 'Yew', 'Zircon', 'Antelope', 'Bison',
    'Cobra', 'Desert', 'Echidna', 'Falconry', 'Garnet', 'Hippogriff', 'Inchworm', 'Jellyfish', 'Koala', 'Labrador',
    'Mantis', 'Narwhal', 'Orchid', 'Panther', 'Quartz', 'Raccoon', 'Starfish', 'Toucan', 'Unicorn', 'Vulture',
    'Wombat', 'Xenon', 'Yak', 'Zealot', 'Aardvark', 'Baboon', 'Cheetah', 'Dromedary', 'Eel', 'Fox',
    'Gibbon', 'Hamster', 'Iguana', 'Jackrabbit', 'Kingfisher', 'Lynx', 'Manatee', 'Nightingale', 'Owl', 'Platypus',
    'Quetzal', 'Rhinoceros', 'Salamander', 'Tortoise', 'Uakari', 'Vicuna', 'Walrus', 'Xerus', 'Yakut', 'Zebra',
    'Amaranth', 'Bracken', 'Cypress', 'Dahlia', 'Edelweiss', 'Fern', 'Gardenia', 'Honeysuckle', 'Iris', 'Jasmine',
    'Kudzu', 'Lavender', 'Magnolia', 'Narcissus', 'Orchid', 'Poppy', 'Quince', 'Rose', 'Sunflower', 'Tulip',
    'Umbrella', 'Violet', 'Waterlily', 'Xerophyte', 'Yucca', 'Zinnia', 'Acacia', 'Bluebell', 'Camellia', 'Daisy',
    'Eucalyptus', 'Ficus', 'Geranium', 'Hibiscus', 'Impatiens', 'Juniper', 'Kalanchoe', 'Lilac', 'Mimosa', 'Nandina',
    'Oleander', 'Petunia', 'Quercus', 'Redwood', 'Sagebrush', 'Thyme', 'Umbrella', 'Verbena', 'Willow', 'Xylosma',
    'Yarrow', 'Zelkova'
]

# %%
first = '''
  -----
  |   |
  |
  |
  |
 ---
'''
secound = '''
  -----
  |   |
  |   O
  |
  |
 ---
'''
third ='''
  -----
  |   |
  |   O
  |   |
  |
 ---
'''
fourth = '''
  -----
  |   |
  |   O
  |  /|
  |
 ---
'''
fiveth = '''
  -----
  |   |
  |   O
  |  /|\
  |
 ---
'''
sixth = '''
  -----
  |   |
  |   O
  |  /|\
  |  /
 ---
'''
sevemth = '''
  -----
  |   |
  |   O
  |  /|\
  |  / \
 ---
'''
logo = '''I apologize for missing some elements. Let's enhance the ASCII art to include more game-related details. Here's an updated version:
Copy     _____
    |/    |     _    _    ____    _   _    ____    __  __    ____    _   _
    |     |    | |  | |  / __ \  | \ | |  / __ \  |  \/  |  / __ \  | \ | |
    |     O    | |__| | | |  | | |  \| | | |  | | | \  / | | |  | | |  \| |
    |    /|\   |  __  | | |  | | | . ` | | |  | | | |\/| | | |  | | | . ` |
    |    / \   | |  | | | |__| | | |\  | | |__| | | |  | | | |__| | | |\  |
    |          |_|  |_|  \____/  |_| \_|  \____/  |_|  |_|  \____/  |_| \_|
 ___|___       
/       \      .<>-+=\/*_,."The Classic Word Guessing Game",.
\________\     
'''
# Out:
# <>:57: SyntaxWarning: invalid escape sequence '\ '
# <>:57: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\sokhi\AppData\Local\Temp\ipykernel_13852\993362587.py:57: SyntaxWarning: invalid escape sequence '\ '
#   logo = '''I apologize for missing some elements. Let's enhance the ASCII art to include more game-related details. Here's an updated version:

# %%
print('Welcome to Hangman!')

list_words = words_for_day_7.words_for_day_7

random_word = random.choice(list_words)
word_length = len(random_word)

chances = 7
display = ['_'] * word_length
guessed_letters = set()

while chances > 0 and '_' in display:
    print(' '.join(display))
    print(f"Chances left: {chances}")
    print(f"Guessed letters: {' '.join(sorted(guessed_letters))}")
    
    user_input = input('Choose a letter: ').lower()
    
    if len(user_input) != 1 or not user_input.isalpha():
        print("Please enter a single letter.")
        continue
    
    if user_input in guessed_letters:
        print("You've already guessed that letter. Try again.")
        continue
    
    guessed_letters.add(user_input)
    
    if user_input in random_word:
        for i in range(word_length):
            if random_word[i] == user_input:
                display[i] = user_input
        print("Good guess!")
    else:
        chances -= 1
        print("Wrong guess.")

if '_' not in display:
    print("Congratulations! You've guessed the word:", random_word)
else:
    print("Game over. The word was:", random_word)
# Out:
# Welcome to Hangman!
# _ _ _ _ _
# Chances left: 7
# Guessed letters:
# Good guess!
# _ a _ _ _
# Chances left: 7
# Guessed letters: a
# Wrong guess.
# _ a _ _ _
# Chances left: 6
# Guessed letters: a e
# Wrong guess.
# _ a _ _ _
# Chances left: 5
# Guessed letters: a e q
# Wrong guess.
# _ a _ _ _
# Chances left: 4
# Guessed letters: a e p q
# Wrong guess.
# _ a _ _ _
# Chances left: 3
# Guessed letters: a e p q x
# Wrong guess.
# _ a _ _ _
# Chances left: 2
# Guessed letters: a c e p q x
# You've already guessed that letter. Try again.
# _ a _ _ _
# Chances left: 2
# Guessed letters: a c e p q x
# Wrong guess.
# _ a _ _ _
# Chances left: 1
# Guessed letters: a b c e p q x
# Wrong guess.
# Game over. The word was: Yakut

# %%
import random
import words_for_day_7
import funs_for_day_7

print (funs_for_day_7.logo)
print('Welcome')
print('Good luck')

list_words = words_for_day_7.words_for_day_7
word_x = random.choice(list_words)
len_word_X = len(word_x)

display = []
display += "_" * len_word_X
print(display)

chances = 7

while chances > 0 and "_" in display:
    user_input = input('Guess a letter: ').lower()
    if chances == 6:
        print (funs_for_day_7.first)
    elif chances == 5:
        print  (funs_for_day_7.secound)
    elif chances == 4:
        print(funs_for_day_7.third)
    elif chances == 3:
        print(funs_for_day_7.fourth)
    elif chances == 2:
        print(funs_for_day_7.fiveth)
    elif chances == 1:
        print(funs_for_day_7.sixth)
    elif chances == 0:
        print(funs_for_day_7.sevemth)
    else:
        print('...')

    for index in range(len(word_x)):
        if word_x[index] == user_input:
            display[index] = user_input

    if user_input not in word_x:
        chances -= 1
        print(f'Wrong guess. You have {chances} chances left.')
    
    print ("" .join(display))

if "_" not in display:
    print('*************************************Congratulations! You guessed the word.*********************************')
else:
    print(f"********************Sorry, you ran out of chances. The word was: {word_x} **********************************")
# Out:
# c:\Users\sokhi\Desktop\Python\day 7\funs_for_day_7.py:57: SyntaxWarning: invalid escape sequence '\ '
#   logo = '''I apologize for missing some elements. Let's enhance the ASCII art to include more game-related details. Here's an updated version:
# I apologize for missing some elements. Let's enhance the ASCII art to include more game-related details. Here's an updated version:
# Copy     _____
#     |/    |     _    _    ____    _   _    ____    __  __    ____    _   _
#     |     |    | |  | |  / __ \  | \ | |  / __ \  |  \/  |  / __ \  | \ | |
#     |     O    | |__| | | |  | | |  \| | | |  | | | \  / | | |  | | |  \| |
#     |    /|\   |  __  | | |  | | | . ` | | |  | | | |\/| | | |  | | | . ` |
#     |    / \   | |  | | | |__| | | |\  | | |__| | | |  | | | |__| | | |\  |
#     |          |_|  |_|  \____/  |_| \_|  \____/  |_|  |_|  \____/  |_| \_|
#  ___|___
# /       \      .<>-+=\/*_,."The Classic Word Guessing Game",.
# \________\
#
# Welcome
# Good luck
# ...
