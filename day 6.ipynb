# %%
def move_around_the_map():
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    move()
    turn_left()
    move()
    move()
    turn_left()
    move()
    move()
    turn_left()
    move()
    turn_left()
    move()
#https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Alone&url=worlds%2Ftutorial_en%2Falone.json
#use the link

# %%
turn_left()
move()
turn_left()
turn_left()
turn_left()
move()
turn_left()
turn_left()
turn_left()
move()
turn_left()
turn_left()
turn_left()
move()
turn_left()
turn_left()
turn_left()

#https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Alone&url=worlds%2Ftutorial_en%2Falone.json
#use the link

# %%
def jump_over ():
    move()
    turn_left()
    move()
    turn_left()
    turn_left()
    turn_left()
    move()
    turn_left()
    turn_left()
    turn_left()
    move()
    turn_left()
for x in range(0,6):
    jump_over()
#https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json
#use specialy this link

# %%
#ctrl+]
#to tab all salected code

# %%
#while Item condition:
def jump_over ():
    move()
    turn_left()
    move()
    turn_left()
    turn_left()
    turn_left()
    move()
    turn_left()
    turn_left()
    turn_left()
    move()
    turn_left()
chackpoint = 6
while at_goal() != True:
    jump_over()

# %%
#using for loop is recomended while using each Item in any data
#whan the condition will not become false
# printing each move in the process
#while chacking each item for any condition using while loop is recomended
#if the condition in while loop will not become false it become infinite loop

# %%
while at_goal() != True:
    while  wall_in_front() == False:
        move()
    while  wall_in_front() == True:
        turn_left()
        move()
        turn_left()
        turn_left()
        turn_left()
        move()
        turn_left()
        turn_left()
        turn_left()
        move()
        turn_left()
    #use specialy this link
    #https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%203&url=worlds%2Ftutorial_en%2Fhurdle3.json

# %%
def turn_right():
    turn_left()
    turn_left()
    turn_left()

def jump():
    turn_left()
    while wall_in_front() == False:
        move()
    turn_right()
    move()
    turn_right()
    while front_is_clear():
        move()
    turn_left()

while not at_goal():
    if front_is_clear():
        move()
    else:
        jump()
